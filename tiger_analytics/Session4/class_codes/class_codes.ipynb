# %% [markdown]
# ## Oops in Python

# %% [markdown]
# file handler using open()
# file handler and json module
#
# Python -  Reader()
# - read any delimited file (, |, tab)
# - read json files
# - how many rows and columns a delimited file has
# - how many fields json file has
#
# Python Class (Account) - Information for a given person's bank account
# - Constructor that can take the initial balance in a user's account
# - Methods to update balance when money is deposited or withdrawn
# - First Name, Last Name, Age, Address, Adhaar Number of a the account holder

# %%
class Account():
    
    def __init__(self,balance,first_name,last_name,age,address,adhaar_number):
        self.balance = balance
        self.first_name = first_name
        self.last_name = last_name
        self.age = age
        self.address = address
        self.adhaar_number = adhaar_number

# %%
person1 = Account(balance = 400,
                  first_name="abc",
                  last_name="def",
                  age=50,
                  address="foabfoba",
                  adhaar_number=123456)

# %%
print(dir(person1))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'address', 'adhaar_number', 'age', 'balance', 'first_name', 'last_name']

# %%
person1.first_name
# Out:
# 'abc'

# %%
person1.address
# Out:
# 'foabfoba'

# %%
person2 = Account(balance = 200,
                  first_name="cbc",
                  last_name="ef",
                  age=50,
                  address="foba",
                  adhaar_number=123)

# %%
person2.first_name
# Out:
# 'cbc'

# %%
class Account():
    
    def __init__(self,balance):
        self.balance = balance
        self.transaction_history = []
        
    def withdraw(self,amount):
        self.balance = self.balance - amount
        print(f"New balance is {self.balance} and amount withdrawn is {amount}") 
        self.transaction_history.append({'withdraw':amount})
    
    def deposit(self,amount):
        self.balance = self.balance + amount
        print(f"New balance is {self.balance} and amount deposited is {amount}")
        self.transaction_history.append({'deposit':amount})

# %% [markdown]
# Extend this class and create a method called `deposit()` that will update the balance and print out how much money was deposited
#
# Create an object and test the usage of `deposit()`
#
# Modify the `__init__`,`deposit` and `withdraw` methods so that a transaction history is recorded

# %%
p1 = Account(balance=800)

# %%
p1.transaction_history
# Out:
# []

# %%
p1.withdraw(100)
# Out:
# New balance is 700 and amount withdrawn is 100

# %%
p1.transaction_history
# Out:
# [{'withdraw': 100}]

# %%
p1.deposit(20)
# Out:
# New balance is 720 and amount deposited is 20

# %%
p1.transaction_history
# Out:
# [{'withdraw': 100}, {'deposit': 20}]

# %% [markdown]
# Python -  Reader()
# - read any delimited file (, |, tab)
# - read json files
# - how many rows and columns a delimited file has
# - how many keys json file has

# %% [markdown]
# - constructor
# - attributes/data_elements
# - methods

# %%
import csv
import json

class Reader():
    def __init__(self,path):
        self.path = path
        self.keys = None
        self.rows = None
        self.cols = None
        self.col_names = None
    
    def read_flat_file(self,delimiter):
        data = []
        with open(self.path,"r",encoding="utf-8") as f:
            reader = csv.DictReader(f,delimiter=delimiter)
            for row in reader:
                data.append(row)
        self.rows = len(data)
        self.cols = len(data[0])
        self.col_names = data[0].keys()
        return data 
    
    def read_json(self):
        with open(self.path,"r",encoding="utf-8") as f:
            raw_json = f.read()
        json_data = json.loads(raw_json)
        self.keys = json_data.keys()
        return json_data
### Names of columns in flat file and store them as class attribute

# %%
path = "/Users/gunnvantsaini/Library/CloudStorage/OneDrive-Personal/Work/Vired/Content/corp_trainings/tiger_analytics/data/tweets_assignment.txt"
r = Reader(path)

# %%
r.rows

# %%
r.cols

# %%
r.read_flat_file("|")[0:2]
# Out:
# [{'Tweet_Date': 'Thu Dec 26 123415 0000 2013',
#   'Tweet_Text': 'ashdubey ratigirl FirstpostBiz First economic move by AamAadmiParty  How come it has gone down in Guj',
#   'Tweet_Handle': 'maverickenator'},
#  {'Tweet_Date': 'Thu Dec 26 123413 0000 2013',
#   'Tweet_Text': 'RT anandpassion Growing popularity can seen as AAP websites Rank 275 in India highest ever for a political party JoinAAP ankitlal Aam',
#   'Tweet_Handle': 'aapkask'}]

# %%
r.cols
# Out:
# 3

# %%
r.rows
# Out:
# 14273

# %%
r.col_names
# Out:
# dict_keys(['Tweet_Date', 'Tweet_Text', 'Tweet_Handle'])

# %%
from utils import Reader

# %% [markdown]
# ## SQL like operations in python
#
# - Read data inside pandas (sql like library in python)
# - Data Analysis:
#     - Aggregate operations
#     - Window functions
#     - Groupby tasks
#     - Joins
#     - Filter
#     - Sort data

# %%
import pandas as pd

# %%
path = "/Users/gunnvantsaini/Library/CloudStorage/OneDrive-Personal/Work/Vired/Content/corp_trainings/tiger_analytics/data/athlete_events.csv"
data = pd.read_csv(path)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head(2) ## select * from table limit 2;
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
data['Name'] ## select name from data;
# Out:
# 0                        A Dijiang
# 1                         A Lamusi
# 2              Gunnar Nielsen Aaby
# 3             Edgar Lindenau Aabye
# 4         Christine Jacoba Aaftink
#                     ...
# 271111                  Andrzej ya
# 271112                    Piotr ya
# 271113                    Piotr ya
# 271114          Tomasz Ireneusz ya
# 271115          Tomasz Ireneusz ya
# Name: Name, Length: 271116, dtype: object

# %%
data['Name'].head(2)
# Out:
# 0    A Dijiang
# 1     A Lamusi
# Name: Name, dtype: object

# %%
## If I need to see column Name and Age and first 5 rows?
data[['Name','Age']].head(5)
# Out:
#                        Name   Age
# 0                 A Dijiang  24.0
# 1                  A Lamusi  23.0
# 2       Gunnar Nielsen Aaby  24.0
# 3      Edgar Lindenau Aabye  34.0
# 4  Christine Jacoba Aaftink  21.0

# %%
data.shape
# Out:
# (271116, 15)

# %% [markdown]
# #### Write a query which selects the following columns:
#  - Name
#  - Event
#  - Medal
#
# Show first 100 rows

# %%
data[['Name','Event','Medal']].head(100)
# Out:
#                                   Name                             Event Medal
# 0                            A Dijiang       Basketball Men's Basketball   NaN
# 1                             A Lamusi      Judo Men's Extra-Lightweight   NaN
# 2                  Gunnar Nielsen Aaby           Football Men's Football   NaN
# 3                 Edgar Lindenau Aabye       Tug-Of-War Men's Tug-Of-War  Gold
# 4             Christine Jacoba Aaftink  Speed Skating Women's 500 metres   NaN
# ..                                 ...                               ...   ...
# 95                Olav Augunson Aarnes         Athletics Men's High Jump   NaN
# 96                 Mika Lauri Aarnikka   Sailing Men's Two Person Dinghy   NaN
# 97                 Mika Lauri Aarnikka   Sailing Men's Two Person Dinghy   NaN
# 98  Jamale (Djamel-) Aarrass (Ahrass-)      Athletics Men's 1,500 metres   NaN
# 99              Dagfinn Sverre Aarskog              Bobsleigh Men's Four   NaN
#
# [100 rows x 3 columns]

# %%
### How to filter the data (where clause)
# table[logical condition]
data.head(5)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
## Only that subset of data where the games were played in year 1992
data[data['Games']=="1992 Summer"].head(2)
# Out:
#     ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 0    1            A Dijiang   M  24.0   180.0    80.0    China  CHN
# 96  33  Mika Lauri Aarnikka   M  24.0   187.0    76.0  Finland  FIN
#
#           Games  Year  Season       City       Sport  \
# 0   1992 Summer  1992  Summer  Barcelona  Basketball
# 96  1992 Summer  1992  Summer  Barcelona     Sailing
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 96  Sailing Men's Two Person Dinghy   NaN

# %%
### All the rows where players are from China
data[data['Team']=="China"].head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN

# %%
data[data['Games']=="1992 Summer"].head(2)
# Out:
#     ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 0    1            A Dijiang   M  24.0   180.0    80.0    China  CHN
# 96  33  Mika Lauri Aarnikka   M  24.0   187.0    76.0  Finland  FIN
#
#           Games  Year  Season       City       Sport  \
# 0   1992 Summer  1992  Summer  Barcelona  Basketball
# 96  1992 Summer  1992  Summer  Barcelona     Sailing
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 96  Sailing Men's Two Person Dinghy   NaN

# %%
data.query("Games=='1992 Summer'").head(2)
# Out:
#     ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 0    1            A Dijiang   M  24.0   180.0    80.0    China  CHN
# 96  33  Mika Lauri Aarnikka   M  24.0   187.0    76.0  Finland  FIN
#
#           Games  Year  Season       City       Sport  \
# 0   1992 Summer  1992  Summer  Barcelona  Basketball
# 96  1992 Summer  1992  Summer  Barcelona     Sailing
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 96  Sailing Men's Two Person Dinghy   NaN

# %%
data.query("Team == 'China'").head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN

# %%
data.query("Year==1992").head(2)
# Out:
#    ID                      Name Sex   Age  Height  Weight         Team  NOC  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0        China  CHN
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
#
#          Games  Year  Season         City          Sport  \
# 0  1992 Summer  1992  Summer    Barcelona     Basketball
# 6  1992 Winter  1992  Winter  Albertville  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 6  Speed Skating Women's 500 metres   NaN

# %%
### Rows where the Age was less than 26 years and the games happened in 1992
data.query("Age<26 and Year==1992").head(2)
# Out:
#    ID                      Name Sex   Age  Height  Weight         Team  NOC  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0        China  CHN
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
#
#          Games  Year  Season         City          Sport  \
# 0  1992 Summer  1992  Summer    Barcelona     Basketball
# 6  1992 Winter  1992  Winter  Albertville  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 6  Speed Skating Women's 500 metres   NaN

# %%
### Rows where the team is from either china or norway?
data.query("Team=='China' or Team == 'Norway'").head()
# Out:
#     ID                Name Sex   Age  Height  Weight    Team  NOC  \
# 0    1           A Dijiang   M  24.0   180.0    80.0   China  CHN
# 1    2            A Lamusi   M  23.0   170.0    60.0   China  CHN
# 59  20  Kjetil Andr Aamodt   M  20.0   176.0    85.0  Norway  NOR
# 60  20  Kjetil Andr Aamodt   M  20.0   176.0    85.0  Norway  NOR
# 61  20  Kjetil Andr Aamodt   M  20.0   176.0    85.0  Norway  NOR
#
#           Games  Year  Season         City          Sport  \
# 0   1992 Summer  1992  Summer    Barcelona     Basketball
# 1   2012 Summer  2012  Summer       London           Judo
# 59  1992 Winter  1992  Winter  Albertville  Alpine Skiing
# 60  1992 Winter  1992  Winter  Albertville  Alpine Skiing
# 61  1992 Winter  1992  Winter  Albertville  Alpine Skiing
#
#                                Event   Medal
# 0        Basketball Men's Basketball     NaN
# 1       Judo Men's Extra-Lightweight     NaN
# 59      Alpine Skiing Men's Downhill     NaN
# ...

# %% [markdown]
# ### Sort data

# %%
print(dir(data))
# Out:
# ['Age', 'City', 'Event', 'Games', 'Height', 'ID', 'Medal', 'NOC', 'Name', 'Season', 'Sex', 'Sport', 'T', 'Team', 'Weight', 'Year', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_REVERSED', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__array_wrap__', '__bool__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__rad
# ...

# %%
### Find out the age of the oldest 10 athletes who have participated in olympics

# %%
data.head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN

# %%
data.sort_values(by="Age",ascending=False).drop_duplicates().head(10)
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 257054  128719          John Quincy Adams Ward   M  97.0     NaN     NaN
# 98118    49663                   Winslow Homer   M  96.0     NaN     NaN
# 60863    31173      Thomas Cowperthwait Eakins   M  88.0     NaN     NaN
# 9371      5146           George Denholm Armour   M  84.0     NaN     NaN
# 236912  118789                    Louis Tauzin   M  81.0     NaN     NaN
# 154855   77710            Robert Tait McKenzie   M  81.0     NaN     NaN
# 138812   69729                  Max Liebermann   M  80.0     NaN     NaN
# 170994   85936           Charles Henry Niehaus   M  77.0     NaN     NaN
# 56599    28993                    Albin Dbrich   M  76.0     NaN     NaN
# 170798   85838  William Newzam Prior Nicholson   M  76.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season         City  \
# 257054  United States  USA  1928 Summer  1928  Summer    Amsterdam
# ...

# %% [markdown]
# Class Excercise:
#
# Read the data called `starbucks.csv` An ideal diet should contain optimum level of nutrients can you find out the names of the items on menu that contain:
#
# Upto 450 calories
#
# Upto 40 g protein
#
# Upto 10 g fat
#
# Upto 40 g Carbs
#
# Upto 5 g fibre

# %%
path = "/Users/gunnvantsaini/Library/CloudStorage/OneDrive-Personal/Work/Vired/Content/corp_trainings/tiger_analytics/data/starbucks.csv"
starbucks = pd.read_csv(path)
starbucks.head(2)
# Out:
#            Name  Calories  Fat  Carb  Fiber  Protein
# 0  Chonga Bagel       300  5.0    50      3       12
# 1  8-Grain Roll       380  6.0    70      7       10

# %%
q="Calories<=450 and Protein<=40 and Fat<=10 and Carb<=40 and Fiber<=5"
starbucks.query(q)['Name']
# Out:
# 10                                Chewy Chocolate Cookie
# 25          Everybody's Favorite - Bantam Bagel (2 Pack)
# 27                             Frappuccino® Cookie Straw
# 28                 French Toast - Bantam Bagels (2 Pack)
# 39                             Petite Vanilla Bean Scone
# 48                                   Strawberry Cake Pop
# 49                  The Classic - Bantam Bagels (2 Pack)
# 77                                     Birthday Cake Pop
# 78                                    Chocolate Cake Pop
# 79                  Chocolate Chip Cookie Dough Cake Pop
# 80                                       Pirate Cake Pop
# 83                           Classic Whole-Grain Oatmeal
# 87     Reduced-Fat Turkey Bacon & Cage Free Egg White...
# 92           Sous Vide Egg Bites: Egg White & Red Pepper
# 106                                    Berry Trio Yogurt
# 111                             Organic Avocado (Spread)
# Name: Name, dtype: object

# %%
### Groupby tasks
path = "/Users/gunnvantsaini/Library/CloudStorage/OneDrive-Personal/Work/Vired/Content/corp_trainings/tiger_analytics/data/stores.csv"
stores = pd.read_csv(path)

# %%
stores.head(2)
# Out:
#    Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2013-152156  11-09-2013  11-12-2013  Second Class    CG-12520
# 1       2  CA-2013-152156  11-09-2013  11-12-2013  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
## Average Profit by city ==> select city, average(profit) from stores groupby city;
stores.groupby('City')['Profit'].mean()
##table.groupby(grp_col)[agg_col].agg()
# Out:
# City
# Aberdeen         6.630000
# Abilene         -3.758400
# Akron           -8.887410
# Albuquerque     45.292007
# Alexandria      19.913644
#                   ...
# Woonsocket      19.669775
# Yonkers        184.517047
# York           -20.433840
# Yucaipa         13.208000
# Yuma          -116.497725
# Name: Profit, Length: 531, dtype: float64

# %%
stores.groupby('City').agg({'Profit':'mean','Discount':'max'})
# Out:
#                  Profit  Discount
# City
# Aberdeen       6.630000       0.0
# Abilene       -3.758400       0.8
# Akron         -8.887410       0.7
# Albuquerque   45.292007       0.2
# Alexandria    19.913644       0.0
# ...                 ...       ...
# Woonsocket    19.669775       0.0
# Yonkers      184.517047       0.4
# York         -20.433840       0.7
# Yucaipa       13.208000       0.0
# Yuma        -116.497725       0.7
#
# [531 rows x 2 columns]

# %%
stores.groupby('City').agg({'Profit':['mean','min'],'Discount':'max'})
# Out:
#                  Profit           Discount
#                    mean       min      max
# City
# Aberdeen       6.630000    6.6300      0.0
# Abilene       -3.758400   -3.7584      0.8
# Akron         -8.887410  -80.9955      0.7
# Albuquerque   45.292007   -5.6943      0.2
# Alexandria    19.913644    0.0000      0.0
# ...                 ...       ...      ...
# Woonsocket    19.669775   13.8915      0.0
# Yonkers      184.517047 -264.9208      0.4
# York         -20.433840  -50.8704      0.7
# Yucaipa       13.208000   13.2080      0.0
# Yuma        -116.497725 -479.9880      0.7
#
# [531 rows x 3 columns]

# %%
### Average profit by Segment and City
stores.groupby(['Segment','City']).agg({'Profit':'mean'})
# Out:
#                              Profit
# Segment     City
# Consumer    Aberdeen       6.630000
#             Abilene       -3.758400
#             Akron        -11.610200
#             Albuquerque    9.628450
#             Alexandria    10.528933
# ...                             ...
# Home Office Wilmington   133.970367
#             Wilson        -5.412000
#             Woodstock      0.910000
#             Yonkers       47.312600
#             Yuma        -257.936400
#
# [1026 rows x 1 columns]

# %% [markdown]
# Consider the data set [audit.csv](https://raw.githubusercontent.com/Gunnvant/PythonForModellers/master/Data/audit.csv), it has characteristics of 2000 tax returns, the data set includes the following variables:
# - ID: Unique Identifier for each person
# - Age: Age of person
# - Employment: Type of Employment
# - Education: Highest level of education
# - Marital: Current Marital Status
# - Occupation: Type of occupation
# - Income: Amount of Income declared
# - Gender: Gender of Person
# - Deductions: Total amount of expenses that a person claims in their financial statements
# - Hours: Average hours worked on a weekly basis
# - RISK_Adjustment: The continuous target variable; this variable records the monetary amount of any adjustment to the person’s financial claims as a result of a productive audit. This variable is a measure of the size of the risk associated with the person.
# - TARGET_Adjusted: The binary target variable for classification modeling (0/1), indicating nonproductive and productive audits, respectively. Productive audits are those that result in an adjustment being made to a client’s financial statement.
#
# **Q1. Compute the %age of productive audits across**
#
# (a) Gender
# (b) Marital Status
# (c) Education level
#
# **Q2: Find the quartiles for**:
#
# (a) Age
# (b) Income
